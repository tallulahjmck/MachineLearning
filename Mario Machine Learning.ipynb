# %%
# !pip install gym_super_mario_bros==7.3.0 nes_py
# Out:
# Requirement already satisfied: gym_super_mario_bros==7.3.0 in c:\programdata\anaconda3\lib\site-packages (7.3.0)
# Requirement already satisfied: nes_py in c:\programdata\anaconda3\lib\site-packages (8.1.8)
# Requirement already satisfied: tqdm>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (4.62.3)
# Requirement already satisfied: pyglet<=1.5.11,>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (1.5.11)
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (1.22.3)
# Requirement already satisfied: gym>=0.17.2 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (0.21.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gym>=0.17.2->nes_py) (2.0.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.48.2->nes_py) (0.4.4)

# %%
# Import the game
import gym_super_mario_bros
# Import the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Import the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
# Setup game
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
# Create a flag - restart or not
done = True
# Loop through each frame in the game
for step in range(100000): 
    # Start the game to begin with 
    if done: 
        # Start the game
        env.reset()
    # Do random actions
    state, reward, done, info = env.step(env.action_space.sample())
    # Show the game on the screen
    env.render()
# Close the game
env.close()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# C:\ProgramData\Anaconda3\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256

# %%
env.close()

# %%
# Install pytorch
# !pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio===0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# Requirement already satisfied: torch==1.10.1+cu113 in c:\programdata\anaconda3\lib\site-packages (1.10.1+cu113)
# Requirement already satisfied: torchvision==0.11.2+cu113 in c:\programdata\anaconda3\lib\site-packages (0.11.2+cu113)
# Requirement already satisfied: torchaudio===0.10.1+cu113 in c:\programdata\anaconda3\lib\site-packages (0.10.1+cu113)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch==1.10.1+cu113) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from torchvision==0.11.2+cu113) (8.4.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from torchvision==0.11.2+cu113) (1.22.3)

# %%
# Install stable baselines for RL stuff
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\programdata\anaconda3\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.22.3)
# Requirement already satisfied: gym==0.21 in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.4.3)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.3.4)
# Requirement already satisfied: torch>=1.8.1 in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.10.1+cu113)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (8.4.0)
# Requirement already satisfied: ale-py~=0.7.4 in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.7.5)
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.5.5.64)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.8.0)
# Requirement already satisfied: tensorboard>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.8.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: importlib-resources in c:\programdata\anaconda3\lib\site-packages (from ale-py~=0.7.4->stable-baselines3[extra]) (5.7.1)
# Requirement already satisfied: importlib-metadata>=4.10.0 in c:\programdata\anaconda3\lib\site-packages (from ale-py~=0.7.4->stable-baselines3[extra]) (4.11.3)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.0.3)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.26.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (4.62.3)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\programdata\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.10.0->ale-py~=0.7.4->stable-baselines3[extra]) (3.6.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.0.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: absl-py>=0.4 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.44.0)
# Requirement already satisfied: protobuf>=3.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.20.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (58.0.4)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.37.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.6.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from absl-py>=0.4->tensorboard>=2.2.0->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.1->stable-baselines3[extra]) (3.10.0.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2021.3)

# %%
# Import Frame Stacker Wrapper and GrayScaling Wrapper
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
# Import Matplotlib to show the impact of frame stacking
from matplotlib import pyplot as plt

# %%
# 1. Create the base environment
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')

# %%
state = env.reset()

# %%
state, reward, done, info = env.step([5])

# %%
plt.figure(figsize=(20,16))
for idx in range(state.shape[3]):
    plt.subplot(1,4,idx+1)
    plt.imshow(state[0][:,:,idx])
plt.show()

# %%
# Import os for file path management
import os 
# Import PPO for algos
from stable_baselines3 import PPO
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=500000, save_path=CHECKPOINT_DIR)

# %%
# This is the AI model started
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, 
            n_steps=512)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
# Train the AI model, this is where the AI model starts to learn
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/PPO_8
# ----------------------------
# | time/              |     |
# |    fps             | 157 |
# |    iterations      | 1   |
# |    time_elapsed    | 3   |
# |    total_timesteps | 512 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 98           |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0025376875 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.725        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 138          |
# |    n_updates            | 3920         |
# |    policy_gradient_loss | 0.00363      |
# |    value_loss           | 354          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 85           |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0004360847 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.57        |
# |    explained_variance   | -0.0118      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0688       |
# |    n_updates            | 3930         |
# |    policy_gradient_loss | -0.000815    |
# |    value_loss           | 0.604        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 81            |
# |    iterations           | 4             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 6.6030654e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.57         |
# |    explained_variance   | -0.105        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.108         |
# |    n_updates            | 3940          |
# |    policy_gradient_loss | 0.000213      |
# |    value_loss           | 0.524         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 5            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0010211413 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | 0.04         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0841       |
# |    n_updates            | 3950         |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 0.326        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 76            |
# |    iterations           | 6             |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 0.00043051422 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.6          |
# |    explained_variance   | -0.0429       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0467        |
# |    n_updates            | 3960          |
# |    policy_gradient_loss | -0.000562     |
# |    value_loss           | 0.23          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 75            |
# |    iterations           | 7             |
# |    time_elapsed         | 47            |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 0.00023673545 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.59         |
# |    explained_variance   | 0.0586        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0529        |
# |    n_updates            | 3970          |
# |    policy_gradient_loss | -0.000876     |
# |    value_loss           | 0.214         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 74           |
# |    iterations           | 8            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 9.948062e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | -0.107       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0581       |
# |    n_updates            | 3980         |
# |    policy_gradient_loss | -0.000392    |
# |    value_loss           | 0.16         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 73            |
# |    iterations           | 9             |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 0.00054883736 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.61         |
# |    explained_variance   | 0.0793        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0512        |
# |    n_updates            | 3990          |
# |    policy_gradient_loss | -0.00103      |
# |    value_loss           | 0.155         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 10           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0006497549 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.62        |
# |    explained_variance   | -0.107       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.042        |
# |    n_updates            | 4000         |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 0.132        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 11           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0004814238 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.62        |
# |    explained_variance   | 0.0265       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0354       |
# |    n_updates            | 4010         |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 0.112        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 12           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 7.879606e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.63        |
# |    explained_variance   | -0.0385      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0404       |
# |    n_updates            | 4020         |
# |    policy_gradient_loss | -0.000223    |
# |    value_loss           | 0.111        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 13           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0011554747 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.63        |
# |    explained_variance   | -0.0176      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.031        |
# |    n_updates            | 4030         |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 0.107        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 14            |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 8.3748135e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.64         |
# |    explained_variance   | -0.0483       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0441        |
# |    n_updates            | 4040          |
# |    policy_gradient_loss | -2.01e-05     |
# |    value_loss           | 0.11          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 15            |
# |    time_elapsed         | 106           |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 0.00058562483 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.64         |
# |    explained_variance   | -0.00627      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.032         |
# |    n_updates            | 4050          |
# |    policy_gradient_loss | -0.002        |
# |    value_loss           | 0.106         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 16            |
# |    time_elapsed         | 113           |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00089139293 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.64         |
# |    explained_variance   | -0.0604       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0462        |
# |    n_updates            | 4060          |
# |    policy_gradient_loss | -0.00221      |
# |    value_loss           | 0.105         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 17           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0023079577 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.57        |
# |    explained_variance   | 0.76         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 98.6         |
# |    n_updates            | 4070         |
# |    policy_gradient_loss | 0.00212      |
# |    value_loss           | 259          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 18            |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 0.00013846473 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.57         |
# |    explained_variance   | 0.853         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 20.5          |
# |    n_updates            | 4080          |
# |    policy_gradient_loss | 0.000306      |
# |    value_loss           | 59.1          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 19           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 9728         |
# | train/                  |              |
# |    approx_kl            | 4.371628e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | -0.00821     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.158        |
# |    n_updates            | 4090         |
# |    policy_gradient_loss | 5.98e-05     |
# |    value_loss           | 0.481        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 20           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0007630595 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.57        |
# |    explained_variance   | -0.0296      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.145        |
# |    n_updates            | 4100         |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 0.424        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 21            |
# |    time_elapsed         | 150           |
# |    total_timesteps      | 10752         |
# | train/                  |               |
# |    approx_kl            | 0.00023981917 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.56         |
# |    explained_variance   | 0.0132        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.113         |
# |    n_updates            | 4110          |
# |    policy_gradient_loss | -0.000418     |
# |    value_loss           | 0.347         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 22            |
# |    time_elapsed         | 158           |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 0.00094692805 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.56         |
# |    explained_variance   | -0.0341       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.147         |
# |    n_updates            | 4120          |
# |    policy_gradient_loss | -0.00183      |
# |    value_loss           | 0.359         |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 23         |
# |    time_elapsed         | 165        |
# |    total_timesteps      | 11776      |
# | train/                  |            |
# |    approx_kl            | 0.00025712 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.55      |
# |    explained_variance   | 0.026      |
# |    learning_rate        | 1e-06      |
# |    loss                 | 0.125      |
# |    n_updates            | 4130       |
# |    policy_gradient_loss | -0.000659  |
# |    value_loss           | 0.285      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 24           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0002688429 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | -0.00456     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.127        |
# |    n_updates            | 4140         |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 0.312        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 25            |
# |    time_elapsed         | 180           |
# |    total_timesteps      | 12800         |
# | train/                  |               |
# |    approx_kl            | 0.00091937487 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.55         |
# |    explained_variance   | 0.00109       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.148         |
# |    n_updates            | 4150          |
# |    policy_gradient_loss | -0.0017       |
# |    value_loss           | 0.28          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 26           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0008039982 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -0.00501     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.153        |
# |    n_updates            | 4160         |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 0.264        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 27           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 0.0011244937 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | -0.00209     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.103        |
# |    n_updates            | 4170         |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 0.231        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 28            |
# |    time_elapsed         | 201           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00096729456 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.54         |
# |    explained_variance   | -0.0338       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0524        |
# |    n_updates            | 4180          |
# |    policy_gradient_loss | -0.00171      |
# |    value_loss           | 0.109         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 29           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 14848        |
# | train/                  |              |
# |    approx_kl            | 0.0009532847 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | -0.06        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0397       |
# |    n_updates            | 4190         |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 0.113        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 30           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0013891349 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | -0.0154      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0559       |
# |    n_updates            | 4200         |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 0.101        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 31            |
# |    time_elapsed         | 224           |
# |    total_timesteps      | 15872         |
# | train/                  |               |
# |    approx_kl            | 0.00019468588 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.57         |
# |    explained_variance   | -0.0406       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0512        |
# |    n_updates            | 4210          |
# |    policy_gradient_loss | -0.000515     |
# |    value_loss           | 0.101         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 32            |
# |    time_elapsed         | 231           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00016431464 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.57         |
# |    explained_variance   | 0.0202        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0552        |
# |    n_updates            | 4220          |
# |    policy_gradient_loss | -0.000462     |
# |    value_loss           | 0.11          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 33           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 16896        |
# | train/                  |              |
# |    approx_kl            | 0.0023762542 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 98.3         |
# |    n_updates            | 4230         |
# |    policy_gradient_loss | 0.00165      |
# |    value_loss           | 312          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 34            |
# |    time_elapsed         | 246           |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 0.00028556888 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | -0.027        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.145         |
# |    n_updates            | 4240          |
# |    policy_gradient_loss | -0.000462     |
# |    value_loss           | 0.627         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 35            |
# |    time_elapsed         | 253           |
# |    total_timesteps      | 17920         |
# | train/                  |               |
# |    approx_kl            | 0.00023003633 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | -0.084        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0969        |
# |    n_updates            | 4250          |
# |    policy_gradient_loss | -0.000569     |
# |    value_loss           | 0.456         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 36            |
# |    time_elapsed         | 260           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00044184877 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0.0274        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0833        |
# |    n_updates            | 4260          |
# |    policy_gradient_loss | -0.00127      |
# |    value_loss           | 0.447         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 37           |
# |    time_elapsed         | 268          |
# |    total_timesteps      | 18944        |
# | train/                  |              |
# |    approx_kl            | 0.0009604213 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -0.0978      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0782       |
# |    n_updates            | 4270         |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 0.304        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 38            |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 0.00044931693 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.54         |
# |    explained_variance   | -0.032        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0914        |
# |    n_updates            | 4280          |
# |    policy_gradient_loss | -0.000826     |
# |    value_loss           | 0.246         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 39            |
# |    time_elapsed         | 283           |
# |    total_timesteps      | 19968         |
# | train/                  |               |
# |    approx_kl            | 0.00054154254 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.54         |
# |    explained_variance   | -0.0845       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0661        |
# |    n_updates            | 4290          |
# |    policy_gradient_loss | -0.000907     |
# |    value_loss           | 0.181         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 40           |
# |    time_elapsed         | 290          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0007659226 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -0.0458      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0597       |
# |    n_updates            | 4300         |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 0.16         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 41          |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 20992       |
# | train/                  |             |
# |    approx_kl            | 0.000615992 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | -0.0343     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0389      |
# |    n_updates            | 4310        |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 0.14        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 42            |
# |    time_elapsed         | 305           |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 0.00062914647 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.57         |
# |    explained_variance   | -0.0473       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0431        |
# |    n_updates            | 4320          |
# |    policy_gradient_loss | -0.00124      |
# |    value_loss           | 0.136         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 43           |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 22016        |
# | train/                  |              |
# |    approx_kl            | 0.0002807565 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | -0.111       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0527       |
# |    n_updates            | 4330         |
# |    policy_gradient_loss | -0.000411    |
# |    value_loss           | 0.12         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 44           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0003589273 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | -0.063       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0482       |
# |    n_updates            | 4340         |
# |    policy_gradient_loss | -0.000626    |
# |    value_loss           | 0.111        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 45            |
# |    time_elapsed         | 327           |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 0.00035067683 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.58         |
# |    explained_variance   | -0.0584       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0866        |
# |    n_updates            | 4350          |
# |    policy_gradient_loss | -0.000844     |
# |    value_loss           | 0.121         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 46            |
# |    time_elapsed         | 334           |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 0.00087368547 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.59         |
# |    explained_variance   | -0.0663       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0668        |
# |    n_updates            | 4360          |
# |    policy_gradient_loss | -0.00171      |
# |    value_loss           | 0.108         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 47           |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 24064        |
# | train/                  |              |
# |    approx_kl            | 0.0001298479 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | -0.0552      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0454       |
# |    n_updates            | 4370         |
# |    policy_gradient_loss | -0.000388    |
# |    value_loss           | 0.103        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 48          |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 6.10376e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 1.19        |
# |    n_updates            | 4380        |
# |    policy_gradient_loss | -0.000787   |
# |    value_loss           | 10.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 49         |
# |    time_elapsed         | 356        |
# |    total_timesteps      | 25088      |
# | train/                  |            |
# |    approx_kl            | 0.00551905 |
# |    clip_fraction        | 0.0244     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.43      |
# |    explained_variance   | 0.543      |
# |    learning_rate        | 1e-06      |
# |    loss                 | 75.2       |
# |    n_updates            | 4390       |
# |    policy_gradient_loss | -0.00566   |
# |    value_loss           | 378        |
# ----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 50            |
# |    time_elapsed         | 363           |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 0.00094159786 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | -0.0853       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.196         |
# |    n_updates            | 4400          |
# |    policy_gradient_loss | -0.00149      |
# |    value_loss           | 2.96          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 51           |
# |    time_elapsed         | 371          |
# |    total_timesteps      | 26112        |
# | train/                  |              |
# |    approx_kl            | 0.0002908723 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -0.051       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.112        |
# |    n_updates            | 4410         |
# |    policy_gradient_loss | 0.000272     |
# |    value_loss           | 3.01         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 52            |
# |    time_elapsed         | 378           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00039142405 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.54         |
# |    explained_variance   | -0.0258       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.237         |
# |    n_updates            | 4420          |
# |    policy_gradient_loss | -0.000673     |
# |    value_loss           | 1.43          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 53            |
# |    time_elapsed         | 385           |
# |    total_timesteps      | 27136         |
# | train/                  |               |
# |    approx_kl            | 0.00058505253 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.55         |
# |    explained_variance   | -0.08         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0969        |
# |    n_updates            | 4430          |
# |    policy_gradient_loss | -0.000275     |
# |    value_loss           | 1.17          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 54            |
# |    time_elapsed         | 393           |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 0.00022487214 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.55         |
# |    explained_variance   | -0.0165       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0873        |
# |    n_updates            | 4440          |
# |    policy_gradient_loss | -0.000721     |
# |    value_loss           | 0.745         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 55          |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 28160       |
# | train/                  |             |
# |    approx_kl            | 0.000169256 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | -0.136      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0664      |
# |    n_updates            | 4450        |
# |    policy_gradient_loss | -0.000333   |
# |    value_loss           | 0.446       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 56            |
# |    time_elapsed         | 408           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00080366526 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.57         |
# |    explained_variance   | 0.0277        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0648        |
# |    n_updates            | 4460          |
# |    policy_gradient_loss | -0.00137      |
# |    value_loss           | 0.369         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 57           |
# |    time_elapsed         | 415          |
# |    total_timesteps      | 29184        |
# | train/                  |              |
# |    approx_kl            | 0.0006839507 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | -0.0865      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0602       |
# |    n_updates            | 4470         |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 0.32         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 58            |
# |    time_elapsed         | 422           |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 0.00018631213 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.57         |
# |    explained_variance   | -0.0123       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0629        |
# |    n_updates            | 4480          |
# |    policy_gradient_loss | -0.000354     |
# |    value_loss           | 0.249         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 59           |
# |    time_elapsed         | 430          |
# |    total_timesteps      | 30208        |
# | train/                  |              |
# |    approx_kl            | 0.0019824859 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | -0.0448      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0766       |
# |    n_updates            | 4490         |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 0.19         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 60           |
# |    time_elapsed         | 437          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0011737434 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | 0.04         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0387       |
# |    n_updates            | 4500         |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 0.151        |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 70             |
# |    iterations           | 61             |
# |    time_elapsed         | 444            |
# |    total_timesteps      | 31232          |
# | train/                  |                |
# |    approx_kl            | 0.000118211494 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.6           |
# |    explained_variance   | -0.0845        |
# |    learning_rate        | 1e-06          |
# |    loss                 | 0.0414         |
# |    n_updates            | 4510           |
# |    policy_gradient_loss | -0.00027       |
# |    value_loss           | 0.173          |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 62            |
# |    time_elapsed         | 452           |
# |    total_timesteps      | 31744         |
# | train/                  |               |
# |    approx_kl            | 0.00041358953 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.6          |
# |    explained_variance   | -0.0724       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0492        |
# |    n_updates            | 4520          |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 0.13          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# ...
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.347        |
# |    explained_variance   | 0.819         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 302           |
# |    n_updates            | 23240         |
# |    policy_gradient_loss | 2.22e-05      |
# |    value_loss           | 444           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 1935          |
# |    time_elapsed         | 149436        |
# |    total_timesteps      | 990720        |
# | train/                  |               |
# |    approx_kl            | 0.00059484807 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.368        |
# |    explained_variance   | 0.737         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 167           |
# |    n_updates            | 23250         |
# |    policy_gradient_loss | -0.000261     |
# |    value_loss           | 393           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 1936         |
# |    time_elapsed         | 149443       |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0020478652 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.42        |
# |    explained_variance   | 0.0617       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 248          |
# |    n_updates            | 23260        |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 668          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 1937          |
# |    time_elapsed         | 149451        |
# |    total_timesteps      | 991744        |
# | train/                  |               |
# |    approx_kl            | 2.3563975e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.451        |
# |    explained_variance   | 0.225         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 687           |
# |    n_updates            | 23270         |
# |    policy_gradient_loss | -9.47e-05     |
# |    value_loss           | 1.16e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 1938         |
# |    time_elapsed         | 149458       |
# |    total_timesteps      | 992256       |
# | train/                  |              |
# |    approx_kl            | 0.0036837608 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.398       |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 217          |
# |    n_updates            | 23280        |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 457          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 1939         |
# |    time_elapsed         | 149465       |
# |    total_timesteps      | 992768       |
# | train/                  |              |
# |    approx_kl            | 6.379059e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.386       |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 280          |
# |    n_updates            | 23290        |
# |    policy_gradient_loss | 0.000132     |
# |    value_loss           | 426          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 1940         |
# |    time_elapsed         | 149472       |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0012776713 |
# |    clip_fraction        | 0.00137      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.348       |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 200          |
# |    n_updates            | 23300        |
# |    policy_gradient_loss | -0.000281    |
# |    value_loss           | 442          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 1941         |
# |    time_elapsed         | 149479       |
# |    total_timesteps      | 993792       |
# | train/                  |              |
# |    approx_kl            | 0.0008200798 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.348       |
# |    explained_variance   | 0.795        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 114          |
# |    n_updates            | 23310        |
# |    policy_gradient_loss | -0.000212    |
# |    value_loss           | 279          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 1942          |
# |    time_elapsed         | 149486        |
# |    total_timesteps      | 994304        |
# | train/                  |               |
# |    approx_kl            | 3.6271755e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.366        |
# |    explained_variance   | 0.82          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 74.7          |
# |    n_updates            | 23320         |
# |    policy_gradient_loss | 0.000476      |
# |    value_loss           | 237           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 1943         |
# |    time_elapsed         | 149493       |
# |    total_timesteps      | 994816       |
# | train/                  |              |
# |    approx_kl            | 3.716105e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.378       |
# |    explained_variance   | 0.507        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 209          |
# |    n_updates            | 23330        |
# |    policy_gradient_loss | 0.000156     |
# |    value_loss           | 407          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 1944          |
# |    time_elapsed         | 149500        |
# |    total_timesteps      | 995328        |
# | train/                  |               |
# |    approx_kl            | 0.00017638225 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.37         |
# |    explained_variance   | 0.548         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 486           |
# |    n_updates            | 23340         |
# |    policy_gradient_loss | -0.00039      |
# |    value_loss           | 747           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 1945         |
# |    time_elapsed         | 149507       |
# |    total_timesteps      | 995840       |
# | train/                  |              |
# |    approx_kl            | 0.0027224175 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.329       |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 21.8         |
# |    n_updates            | 23350        |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 76           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 1946        |
# |    time_elapsed         | 149514      |
# |    total_timesteps      | 996352      |
# | train/                  |             |
# |    approx_kl            | 9.52516e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.292      |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 265         |
# |    n_updates            | 23360       |
# |    policy_gradient_loss | -0.000121   |
# |    value_loss           | 422         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 1947          |
# |    time_elapsed         | 149521        |
# |    total_timesteps      | 996864        |
# | train/                  |               |
# |    approx_kl            | 3.2808864e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.289        |
# |    explained_variance   | 0.758         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 169           |
# |    n_updates            | 23370         |
# |    policy_gradient_loss | 3.08e-05      |
# |    value_loss           | 471           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 1948         |
# |    time_elapsed         | 149529       |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0002628275 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.304       |
# |    explained_variance   | 0.767        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 296          |
# |    n_updates            | 23380        |
# |    policy_gradient_loss | 0.00139      |
# |    value_loss           | 559          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 1949         |
# |    time_elapsed         | 149535       |
# |    total_timesteps      | 997888       |
# | train/                  |              |
# |    approx_kl            | 0.0023007644 |
# |    clip_fraction        | 0.00254      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.286       |
# |    explained_variance   | 0.569        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 589          |
# |    n_updates            | 23390        |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 906          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 1950       |
# |    time_elapsed         | 149543     |
# |    total_timesteps      | 998400     |
# | train/                  |            |
# |    approx_kl            | 0.00054325 |
# |    clip_fraction        | 0.00332    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.253     |
# |    explained_variance   | 0.593      |
# |    learning_rate        | 1e-06      |
# |    loss                 | 174        |
# |    n_updates            | 23400      |
# |    policy_gradient_loss | 0.000675   |
# |    value_loss           | 414        |
# ----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 1951          |
# |    time_elapsed         | 149550        |
# |    total_timesteps      | 998912        |
# | train/                  |               |
# |    approx_kl            | 1.7613289e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.244        |
# |    explained_variance   | 0.742         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 317           |
# |    n_updates            | 23410         |
# |    policy_gradient_loss | 7.23e-05      |
# |    value_loss           | 564           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 1952          |
# |    time_elapsed         | 149557        |
# |    total_timesteps      | 999424        |
# | train/                  |               |
# |    approx_kl            | 2.6618945e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.241        |
# |    explained_variance   | 0.726         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 353           |
# |    n_updates            | 23420         |
# |    policy_gradient_loss | -4.21e-05     |
# |    value_loss           | 533           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 1953         |
# |    time_elapsed         | 149564       |
# |    total_timesteps      | 999936       |
# | train/                  |              |
# |    approx_kl            | 0.0008529731 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | 0.36         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 262          |
# |    n_updates            | 23430        |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 1.2e+03      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 1954          |
# |    time_elapsed         | 149571        |
# |    total_timesteps      | 1000448       |
# | train/                  |               |
# |    approx_kl            | 0.00031600473 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.27         |
# |    explained_variance   | 0.865         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 117           |
# |    n_updates            | 23440         |
# |    policy_gradient_loss | -0.000712     |
# |    value_loss           | 227           |
# -------------------------------------------

# %%
model.save('thisisatestmodel')

# %%
# Load model
model = PPO.load('./train/best_model_1000000')

# %%
state = env.reset()

# %%
# Start the game 
state = env.reset()
# Loop through the game
while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# C:\ProgramData\Anaconda3\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
